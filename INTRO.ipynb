# %% [markdown]
# # Cel notatnika: rozkminić źródła danych i automatyzację pobierania

# %%
import pickle
import pandas as pd
import time
from tqdm import tqdm

with open(f'AllInfo.pkl', 'rb') as f:
    all_info = pickle.load(f)
    
all_info = pd.DataFrame(all_info).T
all_info.reset_index(names='Symbol', inplace=True)
all_info.drop(columns=['WolumenMinimalny', 'WolumenKrok', 'Typ'], inplace=True)

all_info.head()
# Out:
#     Symbol Waluta SpreadAbs SpreadProc                        Opis   TER
# 0  IU5C.DE    EUR      0.01     0.0009    iShares, UCITS, ACC, EUR  0.15
# 1  SYBL.DE    EUR     0.097     0.0022      SPDR, UCITS, DIST, EUR  0.15
# 2  U3O8.DE    EUR     0.034     0.0045     Sprott, UCITS, ACC, EUR  0.85
# 3  UETW.DE    EUR     0.035     0.0011        UBS, UCITS, ACC, EUR   0.1
# 4   XMME.L    USD      0.06      0.001  Xtrackers, UCITS, ACC, USD  0.18

# %% [markdown]
# ## `yfinance`

# %%
# Instalacja biblioteki
# pip install yfinance

import yfinance as yf

# %%
def get_history(symbol: str) -> pd.DataFrame:
    
    if symbol in ['EURPLN', 'CHFPLN', 'USDPLN', 'GBPPLN']: s = symbol+'=X'
    else: s = symbol
    
    ticker = yf.Ticker(s)
    history = ticker.history(start='1900-01-01', end='2025-08-23', interval='1d')
    history = history.loc[:, ['Open', 'Close', 'Volume']]
    history.columns = [f'{symbol}_{c}' for c in history.columns]
    
    return history

get_history('P500.DE').join(get_history('4GLD.DE'), how='outer')
# Out:
#                            P500.DE_Open  P500.DE_Close  P500.DE_Volume  \
# Date
# 2009-11-13 00:00:00+01:00           NaN            NaN             NaN
# 2009-11-16 00:00:00+01:00           NaN            NaN             NaN
# 2009-11-17 00:00:00+01:00           NaN            NaN             NaN
# 2009-11-18 00:00:00+01:00           NaN            NaN             NaN
# 2009-11-19 00:00:00+01:00           NaN            NaN             NaN
# ...                                 ...            ...             ...
# 2025-08-18 00:00:00+02:00   1094.849976    1096.099976           896.0
# 2025-08-19 00:00:00+02:00   1096.150024    1094.349976           472.0
# 2025-08-20 00:00:00+02:00   1092.250000    1086.949951           921.0
# 2025-08-21 00:00:00+02:00   1093.050049    1092.550049          1121.0
# 2025-08-22 00:00:00+02:00   1090.500000    1097.849976          1107.0
#
#                            4GLD.DE_Open  4GLD.DE_Close  4GLD.DE_Volume
# Date
# 2009-11-13 00:00:00+01:00     23.950001      24.090000          348757
# 2009-11-16 00:00:00+01:00     24.250000      24.440001          522167
# 2009-11-17 00:00:00+01:00     24.450001      24.650000          164044
# 2009-11-18 00:00:00+01:00     24.650000      24.650000          293675
# 2009-11-19 00:00:00+01:00     24.680000      24.559999          147696
# ...                                 ...            ...             ...
# 2025-08-18 00:00:00+02:00     92.120003      91.870003          109813
# 2025-08-19 00:00:00+02:00     91.900002      91.665001           90761
# 2025-08-20 00:00:00+02:00     91.785004      92.135002           98643
# 2025-08-21 00:00:00+02:00     92.275002      92.540001          106682
# 2025-08-22 00:00:00+02:00     92.379997      92.629997          145182
#
# [4005 rows x 6 columns]

# %%
symbols_list = list(all_info['Symbol'])
for i, symbol in tqdm(enumerate(symbols_list), total=len(symbols_list)):    
    
    if i == 0:
        data = get_history(symbol)
    else:
        tmp = get_history(symbol)
        data = data.join(tmp, how='outer')
        
    time.sleep(10.0)
# Out:
#   0%|          | 0/1318 [00:10<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 10
#       7     tmp = get_history(symbol)
#       8     data = data.join(tmp, how='outer')
# ---> 10 time.sleep(10.0)
#
# KeyboardInterrupt:

# %%
data.head()
# Out:
#                           IU5C.DE              SYBL.DE              U3O8.DE  \
#                              Open Close Volume    Open Close Volume    Open
# Date
# 2000-01-03 05:00:00+00:00     NaN   NaN    NaN     NaN   NaN    NaN     NaN
# 2000-01-04 05:00:00+00:00     NaN   NaN    NaN     NaN   NaN    NaN     NaN
# 2000-01-05 05:00:00+00:00     NaN   NaN    NaN     NaN   NaN    NaN     NaN
# 2000-01-06 05:00:00+00:00     NaN   NaN    NaN     NaN   NaN    NaN     NaN
# 2000-01-07 05:00:00+00:00     NaN   NaN    NaN     NaN   NaN    NaN     NaN
#
#                                        UETW.DE  ... VERE.DE XMBR.DE        \
#                           Close Volume    Open  ...  Volume    Open Close
# Date                                            ...
# 2000-01-03 05:00:00+00:00   NaN    NaN     NaN  ...     NaN     NaN   NaN
# 2000-01-04 05:00:00+00:00   NaN    NaN     NaN  ...     NaN     NaN   NaN
# 2000-01-05 05:00:00+00:00   NaN    NaN     NaN  ...     NaN     NaN   NaN
# 2000-01-06 05:00:00+00:00   NaN    NaN     NaN  ...     NaN     NaN   NaN
# 2000-01-07 05:00:00+00:00   NaN    NaN     NaN  ...     NaN     NaN   NaN
#
#                                  WELK.DE              XNNV.DE
#                           Volume    Open Close Volume    Open Close Volume
# Date
# 2000-01-03 05:00:00+00:00    NaN     NaN   NaN    NaN     NaN   NaN    NaN
# 2000-01-04 05:00:00+00:00    NaN     NaN   NaN    NaN     NaN   NaN    NaN
# 2000-01-05 05:00:00+00:00    NaN     NaN   NaN    NaN     NaN   NaN    NaN
# 2000-01-06 05:00:00+00:00    NaN     NaN   NaN    NaN     NaN   NaN    NaN
# 2000-01-07 05:00:00+00:00    NaN     NaN   NaN    NaN     NaN   NaN    NaN
#
# [5 rows x 3954 columns]

# %%
data.to_parquet('Data/HistoricalData.parquet.gzip', compression='gzip')

# %%
def get_info(symbol: str) -> dict:
    
    if symbol in ['EURPLN', 'CHFPLN', 'USDPLN', 'GBPPLN']: s = symbol+'=X'
    else: s = symbol
    
    time.sleep(1.0)
    
    ticker = yf.Ticker(s)
    info = ticker.info

    filtered_info = {
        'symbol': info.get('symbol'),
        'shortName': info.get('shortName'),
        'longName': info.get('longName'),
        'language': info.get('language'),
        'fundFamily': info.get('fundFamily'),
        
        'quoteType': info.get('quoteType'),
        'quoteSourceName': info.get('quoteSourceName'),
        
        'currency': info.get('currency'),
        'netExpenseRatio': info.get('netExpenseRatio'),
        'priceHint': info.get('priceHint'),
        
        'trailingAnnualDividendRate': info.get('trailingAnnualDividendRate'),
        'trailingAnnualDividendYield': info.get('trailingAnnualDividendYield'),
        
        'exchange': info.get('exchange'),
        'fullExchangeName': info.get('fullExchangeName'),
        'exchangeTimezoneName': info.get('exchangeTimezoneName'),
        
        'esgPopulated': info.get('esgPopulated')
    }

    return filtered_info

tqdm.pandas()
yf_info = all_info['Symbol'].progress_apply(get_info)

yf_info = pd.DataFrame(list(yf_info))
yf_info = yf_info[yf_info['symbol'].notna()].reset_index(drop=True)
# Out:
#   9%|▉         | 125/1318 [03:19<35:07,  1.77s/it]HTTP Error 404:
#  28%|██▊       | 364/1318 [09:43<26:55,  1.69s/it]HTTP Error 404:
#  89%|████████▉ | 1170/1318 [32:00<03:54,  1.59s/it]HTTP Error 404:
#  96%|█████████▌| 1264/1318 [34:32<01:24,  1.56s/it]HTTP Error 404:
# 100%|██████████| 1318/1318 [36:00<00:00,  1.64s/it]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 37
#      34 yf_info = pd.DataFrame(list(yf_info))
#      35 yf_info = yf_info[yf_info['symbol'].notna()].reset_index(drop=True)
# ---> 37 yf_info.to_parquet('Data/InstrumentsInfo.parquet.gzip', compression='gzip')
#
# File c:\Users\priva\OneDrive\Desktop\Foldery\Finanse osobiste\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\priva\OneDrive\Desktop\Foldery\Finanse osobiste\.venv\Lib\site-packages\pandas\core\frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File c:\Users\priva\OneDrive\Desktop\Foldery\Finanse osobiste\.venv\Lib\site-packages\pandas\io\parquet.py:476, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     474 if isinstance(partition_cols, str):
#     475     partition_cols = [partition_cols]
# --> 476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     480 impl.write(
#     481     df,
#     482     path_or_buf,
#    (...)    488     **kwargs,
#     489 )
#
# File c:\Users\priva\OneDrive\Desktop\Foldery\Finanse osobiste\.venv\Lib\site-packages\pandas\io\parquet.py:67, in get_engine(engine)
#      64         except ImportError as err:
#      65             error_msgs += "\n - " + str(err)
# ---> 67     raise ImportError(
#      68         "Unable to find a usable engine; "
#      69         "tried using: 'pyarrow', 'fastparquet'.\n"
#      70         "A suitable version of "
#      71         "pyarrow or fastparquet is required for parquet "
#      72         "support.\n"
#      73         "Trying to import the above resulted in these errors:"
#      74         f"{error_msgs}"
#      75     )
#      77 if engine == "pyarrow":
#      78     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %%
yf_info.to_parquet('Data/InstrumentsInfo.parquet.gzip', compression='gzip')

# %%
pd.read_parquet('Data/InstrumentsInfo.parquet.gzip')
# Out:
#        symbol                        shortName  \
# 0     IU5C.DE  iShs V-S&P 500 Commun.S.UC.ETFR
# 1     SYBL.DE  SPDR Bloom.15+Y.Gilt UETF     R
# 2     U3O8.DE  HANETF-Sprott Uran.Mnrs ETF   R
# 3     UETW.DE  UBS(I)ETF-U.Cor.MSCI Wld U.ETFR
# 4      XMME.L  XTRACKERS (IE) PUBLIC LIMITED C
# ...       ...                              ...
# 1309   RBOT.L  ISHARES IV PLC ISHS AUTO & ROBO
# 1310  VERE.DE  Vang.FTSE Dev.Eur.ex UK U.ETF R
# 1311  XMBR.DE  Xtrackers MSCI Brazil         I
# 1312  WELK.DE  Amu.S&P Wld Finan.Screen.UETF R
# 1313  XNNV.DE  Xtr.IEXtr.MSCI Innovation ETF R
#
#                                                longName language  \
# 0     iShares V PLC - iShares S&P 500 Communication ...    en-US
# 1                SPDR Bloomberg 15+ Year Gilt UCITS ETF    en-US
# 2          Sprott Uranium Miners UCITS ETF Accumulating    en-US
# 3                 UBS Core MSCI World UCITS ETF USD acc    en-US
# 4          Xtrackers MSCI Emerging Markets UCITS ETF 1C    en-US
# ...                                                 ...      ...
# 1309            iShares Automation & Robotics UCITS ETF    en-US
# 1310  Vanguard FTSE Developed Europe ex UK UCITS ETF...    en-US
# 1311                 Xtrackers MSCI Brazil UCITS ETF 1C    en-US
# 1312  Amundi ETF ICAV - Amundi S&P World Financials ...    en-US
# 1313     Xtrackers MSCI Innovation UCITS ETF 1C USD Acc    en-US
#
#                                        fundFamily quoteType quoteSourceName  \
# 0        BlackRock Asset Management Ireland - ETF       ETF   Delayed Quote
# 1     State Street Global Advisors Europe Limited       ETF   Delayed Quote
# 2                       HANetf Management Limited       ETF   Delayed Quote
# 3           UBS Fund Management (Luxembourg) S.A.       ETF   Delayed Quote
# 4                       DWS Investment S.A. (ETF)       ETF   Delayed Quote
# ...                                           ...       ...             ...
# 1309     BlackRock Asset Management Ireland - ETF       ETF   Delayed Quote
# 1310             Vanguard Group (Ireland) Limited       ETF   Delayed Quote
# 1311                    DWS Investment S.A. (ETF)       ETF   Delayed Quote
# 1312                       Amundi Ireland Limited       ETF   Delayed Quote
# 1313                    DWS Investment S.A. (ETF)       ETF   Delayed Quote
#
#      currency  netExpenseRatio  priceHint exchange fullExchangeName  \
# 0         EUR             0.15        2.0      GER            XETRA
# 1         EUR             0.15        2.0      GER            XETRA
# 2         EUR              NaN        2.0      GER            XETRA
# 3         EUR             0.06        2.0      GER            XETRA
# 4         USD             0.18        2.0      LSE              LSE
# ...       ...              ...        ...      ...              ...
# 1309      USD             0.40        2.0      LSE              LSE
# 1310      EUR              NaN        2.0      GER            XETRA
# 1311      EUR             0.25        2.0      GER            XETRA
# 1312      EUR             0.18        2.0      GER            XETRA
# 1313      EUR             0.30        2.0      GER            XETRA
#
#      exchangeTimezoneName  esgPopulated
# 0           Europe/Berlin         False
# 1           Europe/Berlin         False
# 2           Europe/Berlin         False
# 3           Europe/Berlin         False
# 4           Europe/London         False
# ...                   ...           ...
# 1309        Europe/London         False
# 1310        Europe/Berlin         False
# 1311        Europe/Berlin         False
# 1312        Europe/Berlin         False
# 1313        Europe/Berlin         False
#
# [1314 rows x 14 columns]

# %%
# Utworzenie obiektu ticker dla ETF-a na S&P 500 (SPY)
spy_etf = yf.Ticker("SPY")

# Pobranie danych intraday (co 5 minut) z ostatnich 5 dni
hist_intraday = spy_etf.history(period="5d", interval="5m")

print("Dane intraday dla SPY z ostatnich 5 dni:")
hist_intraday.head()
# Out:
# Dane intraday dla SPY z ostatnich 5 dni:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-08-18 09:30:00-04:00  642.859985  643.445007  642.799988  643.399902
# 2025-08-18 09:35:00-04:00  643.400024  643.585022  643.049988  643.309998
# 2025-08-18 09:40:00-04:00  643.320007  643.419983  642.804993  643.200012
# 2025-08-18 09:45:00-04:00  643.190002  643.799988  643.169983  643.549988
# 2025-08-18 09:50:00-04:00  643.540405  643.559998  642.830017  642.989990
#
#                             Volume  Dividends  Stock Splits  Capital Gains
# Datetime
# 2025-08-18 09:30:00-04:00  2028539        0.0           0.0            0.0
# 2025-08-18 09:35:00-04:00   985418        0.0           0.0            0.0
# 2025-08-18 09:40:00-04:00   798013        0.0           0.0            0.0
# 2025-08-18 09:45:00-04:00   992450        0.0           0.0            0.0
# 2025-08-18 09:50:00-04:00   866464        0.0           0.0            0.0

# %%
# --- Przykład 1: Akcje spółki CD Projekt ---
print("--- Pobieranie danych dla CD Projekt (CDR.WA) ---")
try:
    # Utworzenie obiektu Ticker
    cd_projekt = yf.Ticker("CDR.WA")
    
    # Pobranie słownika z informacjami
    info_cdr = cd_projekt.info
    
    # Wyświetlenie wybranych informacji
    print(f"Pełna nazwa: {info_cdr.get('longName', 'Brak danych')}")
    print(f"Sektor: {info_cdr.get('sector', 'Brak danych')}")
    print(f"Strona WWW: {info_cdr.get('website', 'Brak danych')}")
    print(f"Kapitalizacja rynkowa: {info_cdr.get('marketCap', 'Brak danych'):,}") # Formatowanie liczby
    print("\nOpis działalności:")
    print(info_cdr.get('longBusinessSummary', 'Brak opisu.'))

except Exception as e:
    print(f"Nie udało się pobrać danych dla CDR.WA: {e}")


# --- Przykład 2: ETF na S&P 500 ---
print("\n\n--- Pobieranie danych dla ETF SPDR S&P 500 (SPY) ---")
try:
    # Utworzenie obiektu Ticker
    spy_etf = yf.Ticker("SPY")

    # Pobranie słownika z informacjami
    info_spy = spy_etf.info
    
    # Wyświetlenie wybranych informacji
    print(f"Pełna nazwa: {info_spy.get('longName', 'Brak danych')}")
    print(f"Kategoria funduszu: {info_spy.get('category', 'Brak danych')}")
    print(f"Suma aktywów: {info_spy.get('totalAssets', 'Brak danych'):,}")
    print(f"Stopa dywidendy (yield): {info_spy.get('yield', 0) * 100:.2f}%") # Formatowanie do procentów
    
except Exception as e:
    print(f"Nie udało się pobrać danych dla SPY: {e}")
# Out:
# --- Pobieranie danych dla CD Projekt (CDR.WA) ---
# Pełna nazwa: CD Projekt S.A.
# Sektor: Communication Services
# Strona WWW: https://www.cdprojekt.com
# Kapitalizacja rynkowa: 25,766,916,096
#
# Opis działalności:
# CD Projekt S.A., together its subsidiaries, engages in the development, publishing, and digital distribution of video games for personal computers and video game consoles in Poland. It operates in two segments, CD PROJEKT RED and GOG.com. The company's product portfolio comprises Cyberpunk 2077: Phantom Liberty; Cyberpunk 2077; The Witcher 3: Wild Hunt; The Witcher 2: Assassins of Kings; The Witcher; and GWENT: The Witcher Card Game. It also distributes videogames through GOG.com distribution platform and GOG GALAXY application, as well as online channels. The company also exports its products to rest of Europe, North America, South America, Asia, Australia, and Africa. CD Projekt S.A. was incorporated in 2001 and is headquartered in Warsaw, Poland.
#
#
# --- Pobieranie danych dla ETF SPDR S&P 500 (SPY) ---
# Pełna nazwa: SPDR S&P 500 ETF
# Kategoria funduszu: Large Blend
# Suma aktywów: 652,629,770,240
# Stopa dywidendy (yield): 1.13%

# %%
with open(f'AllInfo.pkl', 'rb') as f:
    all_info = pickle.load(f)

# %%
ticker = yf.Ticker("P500.DE")
ticker.info
# Out:
# {'companyOfficers': [],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 1108.45,
#  'open': 1112.5,
#  'dayLow': 1109.0,
#  'dayHigh': 1115.85,
#  'regularMarketPreviousClose': 1108.45,
#  'regularMarketOpen': 1112.5,
#  'regularMarketDayLow': 1109.0,
#  'regularMarketDayHigh': 1115.85,
#  'volume': 786,
#  'regularMarketVolume': 786,
#  'averageVolume': 1299,
#  'averageVolume10days': 1119,
#  'averageDailyVolume10Day': 1119,
#  'bid': 1114.55,
#  'ask': 1114.9,
#  'bidSize': 1088,
#  'askSize': 1088,
#  'fiftyTwoWeekLow': 864.14,
#  'fiftyTwoWeekHigh': 1162.75,
#  'fiftyDayAverage': 1084.49,
#  'twoHundredDayAverage': 1068.111,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'navPrice': 1294.4316,
#  'currency': 'EUR',
#  'tradeable': False,
#  'fundFamily': 'Invesco Investment Management Limited',
#  'fundInceptionDate': 1274313600,
#  'legalType': 'Exchange Traded Fund',
#  'quoteType': 'ETF',
#  'symbol': 'P500.DE',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'ETF',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'fiftyDayAverageChange': 31.359985,
#  'fiftyDayAverageChangePercent': 0.028916804,
#  'twoHundredDayAverageChange': 47.739014,
#  'twoHundredDayAverageChangePercent': 0.044694807,
#  'netExpenseRatio': 0.05,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1351148400000,
#  'marketState': 'POSTPOST',
#  'shortName': 'InvescoMI S&P 500 ETF         R',
#  'longName': 'Invesco S&P 500 UCITS ETF',
#  'gmtOffSetMilliseconds': 7200000,
#  'market': 'de_market',
#  'esgPopulated': False,
#  'regularMarketDayRange': '1109.0 - 1115.85',
#  'fullExchangeName': 'XETRA',
#  'averageDailyVolume3Month': 1299,
#  'fiftyTwoWeekLowChange': 251.70996,
#  'fiftyTwoWeekLowChangePercent': 0.29128376,
#  'fiftyTwoWeekRange': '864.14 - 1162.75',
#  'fiftyTwoWeekHighChange': -46.900024,
#  'fiftyTwoWeekHighChangePercent': -0.04033543,
#  'fiftyTwoWeekChangePercent': 11.996317,
#  'regularMarketChange': 7.4000244,
#  'regularMarketChangePercent': 0.6676011,
#  'regularMarketPrice': 1115.85,
#  'corporateActions': [],
#  'regularMarketTime': 1757604964,
#  'exchange': 'GER',
#  'messageBoardId': 'finmb_105731420',
#  'exchangeTimezoneName': 'Europe/Berlin',
#  'exchangeTimezoneShortName': 'CEST',
#  'trailingPegRatio': None}
